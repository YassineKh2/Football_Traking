# %%
from IPython.display import Image

# %% [markdown]
# # **Clone the Github Repo**

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git

# %% [markdown]
# # **Setting The Current Directory**

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# %cd /kaggle/working/YOLOv8-DeepSORT-Object-Tracking
# Out:
# /kaggle/working/YOLOv8-DeepSORT-Object-Tracking

# %% [markdown]
# # **Install all dependencies**

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///kaggle/working/YOLOv8-DeepSORT-Object-Tracking
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 71.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 62.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Moving to the required directory**

# %%
# %cd /kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %% [markdown]
# # **Importing the Dataset from the RoboFlow**

# %%
# !pip install roboflow

from roboflow import Roboflow

rf = Roboflow(api_key='iOqPD5zonb3Ou6XZ2Xpe')
project = rf.workspace("moin").project("football_and_players")
dataset = project.version(2).download("yolov5")

# %% [markdown]
# # **Dowloading the required DeepSort files and unzip the files**

# %%
# !pip install gdown

# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# !unzip 'deep_sort_pytorch.zip'

# %% [markdown]
# # **Training the custom model**

# %%
HOME = '/kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# %cd {HOME}

# !python train.py model=yolov8l.pt data=Football_and_players-2/data.yaml epochs=80 imgsz=640

# %% [markdown]
# # **Checking the files inside the train folder**

# %%
# !ls /kaggle/working/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train2/

# %% [markdown]
# # **Printing the F1-Curve**

# %%
Image(filename ="/kaggle/working/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train2/F1_curve.png")

# %% [markdown]
# # **Validate Custom model**

# %%
# !pwd

# %%
# !python val.py model="/kaggle/working/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train2/weights/best.pt" data="/kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/Football_and_players-2/data.yaml"
# Out:
# 2024-04-22 18:55:17.600886: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 18:55:17.600963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-22 18:55:17.602498: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# ...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 13.3MB/s]
# val: Scanning /kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v
# ...

# %% [markdown]
# # **Inference with the custom model**

# %% [markdown]
# **Demo Video**

# %%
# !pip install gdown

# !gdown "https://drive.google.com/file/d/145nFmE1cee9f-VdFpOpfSU1zjoUWNjrC/view?usp=drive_link"
# Out:
# ...
# /opt/conda/lib/python3.10/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=145nFmE1cee9f-VdFpOpfSU1zjoUWNjrC
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/145nFmE1cee9f-VdFpOpfSU1zjoUWNjrC/view?usp=drive_link
# To: /kaggle/working/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/view?usp=drive_link
# 82.4kB [00:00, 3.49MB/s]

# %%
# !python predict.py model='/kaggle/working/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train2/weights/best.pt' source="/kaggle/input/videofootball/testVideo1.mp4" conf=0.01
# Out:
# [2024-04-22 19:11:24,142][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2024-04-22 19:11:26.771541: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 19:11:26.771692: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-22 19:11:26.944708: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.13 torch-2.1.2+cpu CPU
# Fusing layers...
# Model summary: 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# ...

# %%
# %cd /kaggle/working

# %%
# !zip YOLOv8-DeepSORT-Object-Tracking
